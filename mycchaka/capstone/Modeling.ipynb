# %%
import pandas as pd
import numpy as np

from sklearn.model_selection import GridSearchCV
from sklearn.naive_bayes import MultinomialNB
from sklearn.model_selection import cross_val_predict
from sklearn.metrics import accuracy_score
from sklearn.ensemble import RandomForestClassifier

import pickle

# %%
df = pd.read_csv('./Resources/Xy_1.csv').drop('Unnamed: 0', axis = 1)
X = df.iloc[:,:-1]
y = df.iloc[:,-1]

# %%
nb = MultinomialNB()

# %%
accuracy_score(y, cross_val_predict(nb,X,y))

# %%
from Scripts.mk_models import

# %%
gs_rfc = GridSearchCV(RandomForestClassifier(n_estimators=1000),{}, verbose=1, n_jobs=4)

# %%
gs_rfc.fit(X,y).best_score_

# %%
gs_rfc.fit(X,y).best_score_

# %%
from sklearn.linear_model import LogisticRegression

# %%
gs_lr = GridSearchCV(LogisticRegression(),{'C':np.logspace(-4,4,9)}, verbose=1, n_jobs=4)

# %%
gs_lr.fit(X,y).best_score_

# %%
gs_rfc.fit(X2,y).best_score_

# %%
localX = X4
print(gs_rfc.fit(localX,y).best_score_)
print(gs_lr.fit(localX,y).best_score_)

# %%
localX = X3
print(gs_rfc.fit(localX,y).best_score_)
print(gs_lr.fit(localX,y).best_score_)

# %%
gs.fit(X,y)

# %%
gs.best_score_

# %%
gs_2 = GridSearchCV(MultinomialNB(), {'alpha':np.logspace(-4,4,9)}, verbose=3, cv = 5)

# %%
gs_2.fit(X,y)

# %%
gs_2.best_score_

# %%
sUS = X[[col for col in X.columns if col[0] == 's']].sum(axis = 1)
oUS = X[[col for col in X.columns if col[0] == 'o']].sum(axis = 1)
X2 = pd.concat([sUS,oUS], axis=1)
X2.columns = ['self','other']
X2.head()

# %%
gs_2.fit(X2, y)

# %%
gs_2.best_score_

# %%
units = pd.read_pickle('./Resources/unit_attributes.p')

# %%
units = units.applymap(lambda x: x.replace(' ','') if type(x) == str else x)
units
# Out:
#               Unit  Mineral  Vespene  Supply  Build Time  \
# 0              SCV       50        0       1          17
# 1           Marine       50        0       1          25
# 2         Marauder      100       25       2          30
# 3           Reaper       50       50       1          45
# 4            Ghost      200      100       2          40
# 5          Hellion      100        0       2          30
# 6        SiegeTank      150      125       3          45
# 7             Thor      300      200       6          60
# 8           Viking      150       75       2          42
# 9          Medivac      100      100       2          42
# 10           Raven      100      200       2          60
# 11         Banshee      150      100       3          60
# 12   Battlecruiser      400      300       6          90
# 13         Hellbat      100        0       2          30
# 14       WidowMine       75       25       2          40
# ...

# %%
X3 = X[[col for col in X.columns if col.split('_')[1] in units['Unit'].values]]

# %%
gs_2.fit(X3, y)

# %%
gs_2.best_score_

# %%
gs_2.fit(X3,y)

# %%
gs_2.best_score_

# %%
sUS = X3[[col for col in X3.columns if col[0] == 's']].sum(axis = 1)
oUS = X3[[col for col in X3.columns if col[0] == 'o']].sum(axis = 1)
X4 = pd.concat([sUS,oUS], axis=1)
X4.columns = ['self','other']
X4.head()
# Out:
#     self  other
# 0  119.0   67.0
# 1    8.0   25.0
# 2  141.0   74.0
# 3  117.0   61.0
# 4   87.0  103.0

# %%
gs_2.fit(X4,y)

# %%
gs_2.best_score_

# %%
1+1
# Out:
# 2

# %%
1+!
# Out:
#   File "<ipython-input-1-19b23891d7c6>", line 1
#     1+!
#       ^
# SyntaxError: invalid syntax

# %%
X.shape
# Out:
# (5414, 232)

# %%
X3.shape
# Out:
# (5414, 94)

# %%
gs_lr.fit(X3,y).best_score_
# Out:
# Fitting 3 folds for each of 9 candidates, totalling 27 fits
# [Parallel(n_jobs=4)]: Done  20 out of  27 | elapsed:    0.5s remaining:    0.2s
# [Parallel(n_jobs=4)]: Done  27 out of  27 | elapsed:    0.6s finished
# 0.66900628001477647

# %%
gs_rfc.fit(X3,y).best_score_
# Out:
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# [Parallel(n_jobs=4)]: Done   3 out of   3 | elapsed:    5.8s finished
# 0.63465090506095312
