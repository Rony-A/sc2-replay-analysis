# %%
import pandas as pd

# %%
data = pd.read_csv('./../../../../../../mycchakakleinbort/Downloads/tint_8.int.cut8.cut', skiprows=10)

# %%
X = pd.DataFrame([pd.Series(data.iloc[i,:][0].split('  ')) for i in range(data.shape[0])])

# %%
from sklearn.decomposition import PCA

# %%
pca = PCA()

# %%
pca.fit_transform(X)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-50-b27a765bd97a> in <module>()
# ----> 1 pca.fit_transform(X)
#
# /usr/local/lib/python3.6/site-packages/sklearn/decomposition/pca.py in fit_transform(self, X, y)
#     342
#     343         """
# --> 344         U, S, V = self._fit(X)
#     345         U = U[:, :self.n_components_]
#     346
#
# /usr/local/lib/python3.6/site-packages/sklearn/decomposition/pca.py in _fit(self, X)
#     364
#     365         X = check_array(X, dtype=[np.float64, np.float32], ensure_2d=True,
# --> 366                         copy=self.copy)
#     367
#     368         # Handle n_components==None
#
# /usr/local/lib/python3.6/site-packages/sklearn/utils/validation.py in check_array(array, accept_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, warn_on_dtype, estimator)
# ...

# %%
X2 = X.drop([0], axis=1)

# %%
vals = X2.values.reshape(1,95175)[0][:-14].astype(int)

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(50,4))
plt.plot(range(len(vals))[0:500],vals[0:500])
plt.show()

# %%
vals
# Out:
# array(['1', '1', '1', ..., '0', '0', '0'], dtype=object)
